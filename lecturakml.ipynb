# %%
# Import necessary modules
import geopandas as gpd

# No sé por qué, pero para leer el archivo KML, hay que leer primero un shapefile
# Set filepath
fp = "data/L2_data/Europe_borders.shp"

# Read file using gpd.read_file()
data1 = gpd.read_file(fp)


# Set filepath
archivo = "data/Mgdalena.kml"

gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
df = gpd.read_file(archivo, driver='KML')

# %%
# %matplotlib inline
df.plot()
# Out:
# <AxesSubplot: >
